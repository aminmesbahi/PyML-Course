# %% [markdown]
# # Session 5
# ## Visualization using Matplotlib, Seaborn
#
# ```python
# conda install matplotlib
# pip install matplotlib
# ```

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# In editors other than Jupyter, you'll use: plt.show() at the end of all your plotting commands to have the figure pop up in another window.

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Funcational Approach
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
'Hello'
# Out:
# 'Hello'

# %%
print('Hello')
# Out:
# Hello

# %%
plt.plot(x,y,'r') # Matlab format

# %%
plt.plot(x,y,'r.')

# %%
plt.plot(x,y,'r-*')

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
# %config IPCompleter.greedy=True

# %%
# Object Oriented Approach
fig=plt.figure()

axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)

axes.set_xlabel('X Label')

axes.set_ylabel('Y Label')

axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig=plt.figure() # Creates empty figure
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3]) #all values should be between 0 and 1, 0.2 means 20% [left,bottom, width, height]

axes1.plot(x,y)
axes1.set_title('Larger plot')

axes2.plot(y,x)
axes2.set_title('Smaller plot')
# Out:
# Text(0.5, 1.0, 'Smaller plot')

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)
#plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ## Figure Size and DPI

# %%
fig=plt.figure(figsize=(8,2),dpi=200) #inch
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(8,2)) #inch

ax[0].plot(x,y)

ax[1].plot(y,x)

plt.tight_layout()

# %%
fig.savefig('sample_fig.png',dpi=200)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squared')
ax.plot(x,x**3,label='X Cubed')

#ax.legend()
#ax.legend(loc=0) #0 -> Top, Left
ax.legend(loc=1) #1 -> Top, Right
#ax.legend(loc=(0.1,0.1))


#ax.set_title('Title')
#ax.set_ylabel('Y')
#ax.set_xlabel('X')

# %% [markdown]
# ## Plot Appearance

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple',linewidth=3,alpha=0.8,linestyle='--',marker='o',markersize=10,
       markerfacecolor='yellow',markeredgewidth=2,markeredgecolor='red') 
#ax.plot(x,y, color='purple',lw=3,alpha=0.5,ls='--') 
#green, blue, red, #FF3333, RGB
#linestyle: -- : -. -
#marker='o','+',1

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple',lw=2,ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)
